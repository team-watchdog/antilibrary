# %%
#Libraries

# !pip install pandoc langchain gradio chromadb tiktoken clean-text
# !pip install "unstructured[local-inference]"
# !pip install "detectron2@git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2"
# !pip install layoutparser pypdf unidecode

import os
import glob
import pandoc
from io import StringIO
import gradio as gr
import re
import time

from langchain.chains import RetrievalQA
from langchain.llms import OpenAI
from langchain.document_loaders import TextLoader
from langchain.document_loaders import UnstructuredWordDocumentLoader
from langchain.document_loaders import UnstructuredEPubLoader
from langchain.document_loaders import PyPDFLoader


from langchain.indexes import VectorstoreIndexCreator
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma


from html.parser import HTMLParser
import chromadb
# Out:
# Requirement already satisfied: transformers in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (4.29.1)
# Requirement already satisfied: filelock in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (2023.5.5)
# Requirement already satisfied: requests in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (2.29.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->transformers) (2023.5.7)
# Collecting git+https://github.com/huggingface/transformers@
# ERROR: The URL 'git+https://github.com/huggingface/transformers@' has an empty revision (after @) which is not supported. Include a revision after @ or remove @ from the URL.
# Requirement already satisfied: diffusers in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.16.1)
# Requirement already satisfied: accelerate in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.19.0)
# Requirement already satisfied: datasets in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: torch in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (2.0.1)
# Requirement already satisfied: sentencepiece in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.1.99)
# Requirement already satisfied: opencv-python in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (4.6.0.66)
# Requirement already satisfied: openai in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.27.6)
# Requirement already satisfied: gradio in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (3.30.0)
# Requirement already satisfied: langchain in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.0.171)
# Requirement already satisfied: Pillow in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from diffusers) (9.5.0)
# Requirement already satisfied: filelock in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from diffusers) (3.12.0)
# Requirement already satisfied: huggingface-hub>=0.13.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from diffusers) (0.14.1)
# Requirement already satisfied: importlib-metadata in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from diffusers) (6.6.0)
# Requirement already satisfied: numpy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from diffusers) (1.23.5)
# Requirement already satisfied: regex!=2019.12.17 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from diffusers) (2023.5.5)
# Requirement already satisfied: requests in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from diffusers) (2.29.0)
# Requirement already satisfied: packaging>=20.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from accelerate) (6.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (12.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (1.5.3)
# Requirement already satisfied: tqdm>=4.62.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (2023.5.0)
# Requirement already satisfied: aiohttp in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (3.8.4)
# Requirement already satisfied: responses<0.19 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from datasets) (0.18.0)
# Requirement already satisfied: typing-extensions in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch) (2.0.0)
# Requirement already satisfied: setuptools in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (67.7.2)
# Requirement already satisfied: wheel in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.40.0)
# Requirement already satisfied: cmake in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from triton==2.0.0->torch) (3.26.3)
# Requirement already satisfied: lit in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from triton==2.0.0->torch) (16.0.3)
# Requirement already satisfied: aiofiles in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: altair>=4.2.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (5.0.0)
# Requirement already satisfied: fastapi in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.95.1)
# Requirement already satisfied: ffmpy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: gradio-client>=0.2.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.2.4)
# Requirement already satisfied: httpx in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.23.3)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: markupsafe in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.1.2)
# Requirement already satisfied: matplotlib in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: orjson in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (3.8.12)
# Requirement already satisfied: pydantic in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (1.10.7)
# Requirement already satisfied: pydub in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.15.1)
# Requirement already satisfied: python-multipart in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: semantic-version in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.22.0)
# Requirement already satisfied: websockets>=10.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from langchain) (2.0.13)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from langchain) (0.5.7)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: openapi-schema-pydantic<2.0,>=1.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from langchain) (1.2.4)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: jsonschema>=3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.8.0)
# Requirement already satisfied: mdurl~=0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: idna<4,>=2.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->diffusers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->diffusers) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: click>=7.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from fastapi->gradio) (0.26.1)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: sniffio in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from importlib-metadata->diffusers) (3.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.2)
# Requirement already satisfied: six>=1.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.12.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: gradio in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (3.30.0)
# Requirement already satisfied: aiofiles in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (23.1.0)
# Requirement already satisfied: aiohttp in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (3.8.4)
# Requirement already satisfied: altair>=4.2.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (5.0.0)
# Requirement already satisfied: fastapi in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.95.1)
# Requirement already satisfied: ffmpy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.3.0)
# Requirement already satisfied: gradio-client>=0.2.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.2.4)
# Requirement already satisfied: httpx in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.23.3)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.14.1)
# Requirement already satisfied: jinja2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: markupsafe in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.1.2)
# Requirement already satisfied: matplotlib in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.3.3)
# Requirement already satisfied: numpy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (3.8.12)
# Requirement already satisfied: pandas in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (9.5.0)
# Requirement already satisfied: pydantic in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (1.10.7)
# Requirement already satisfied: pydub in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: pygments>=2.12.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.15.1)
# Requirement already satisfied: python-multipart in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: pyyaml in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (6.0)
# Requirement already satisfied: requests in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.29.0)
# Requirement already satisfied: semantic-version in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: typing-extensions in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (4.5.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (0.22.0)
# Requirement already satisfied: websockets>=10.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from altair>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: toolz in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from altair>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: fsspec in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio-client>=0.2.4->gradio) (2023.5.0)
# Requirement already satisfied: packaging in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from gradio-client>=0.2.4->gradio) (23.1)
# Requirement already satisfied: filelock in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->gradio) (3.12.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from huggingface-hub>=0.13.0->gradio) (4.65.0)
# Requirement already satisfied: mdurl~=0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandas->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandas->gradio) (2023.3)
# Requirement already satisfied: click>=7.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->gradio) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->gradio) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->gradio) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->gradio) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->gradio) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->gradio) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from aiohttp->gradio) (1.3.1)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from fastapi->gradio) (0.26.1)
# Requirement already satisfied: certifi in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpx->gradio) (2023.5.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: sniffio in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpx->gradio) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->gradio) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->gradio) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests->gradio) (1.26.15)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio) (3.6.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.2.0->gradio) (0.19.3)
# Requirement already satisfied: uc-micro-py in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio) (1.0.2)
# Requirement already satisfied: six>=1.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->gradio) (1.12.0)
# Requirement already satisfied: python-docx in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.8.11)
# Requirement already satisfied: pdfplumber in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: ebooklib in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.18)
# Requirement already satisfied: lxml>=2.3.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from python-docx) (4.9.2)
# Requirement already satisfied: pdfminer.six==20221105 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfplumber) (20221105)
# Requirement already satisfied: Pillow>=9.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfplumber) (9.5.0)
# Requirement already satisfied: Wand>=0.6.10 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfplumber) (0.6.11)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber) (3.1.0)
# Requirement already satisfied: cryptography>=36.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber) (40.0.2)
# Requirement already satisfied: six in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from ebooklib) (1.12.0)
# Requirement already satisfied: cffi>=1.12 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (1.15.1)
# Requirement already satisfied: pycparser in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber) (2.21)
# Requirement already satisfied: chromadb in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.3.23)
# Requirement already satisfied: tiktoken in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.4.0)
# Requirement already satisfied: clean-text in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: pandas>=1.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (1.5.3)
# Requirement already satisfied: requests>=2.28 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (2.29.0)
# Requirement already satisfied: pydantic>=1.9 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (1.10.7)
# Requirement already satisfied: hnswlib>=0.7 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (0.7.0)
# Requirement already satisfied: clickhouse-connect>=0.5.7 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (0.5.24)
# Requirement already satisfied: sentence-transformers>=2.2.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (2.2.2)
# Requirement already satisfied: duckdb>=0.7.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (0.7.1)
# Requirement already satisfied: fastapi>=0.85.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (0.95.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: numpy>=1.21.6 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (1.23.5)
# Requirement already satisfied: posthog>=2.4.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from chromadb) (4.5.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tiktoken) (2023.5.5)
# Requirement already satisfied: emoji<2.0.0,>=1.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from clean-text) (1.7.0)
# Requirement already satisfied: ftfy<7.0,>=6.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from clean-text) (6.1.1)
# Requirement already satisfied: certifi in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2023.5.7)
# Requirement already satisfied: urllib3>=1.26 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from clickhouse-connect>=0.5.7->chromadb) (1.26.15)
# Requirement already satisfied: pytz in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from clickhouse-connect>=0.5.7->chromadb) (2023.3)
# Requirement already satisfied: zstandard in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from clickhouse-connect>=0.5.7->chromadb) (0.21.0)
# Requirement already satisfied: lz4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from clickhouse-connect>=0.5.7->chromadb) (4.3.2)
# Requirement already satisfied: starlette<0.27.0,>=0.26.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from fastapi>=0.85.1->chromadb) (0.26.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from ftfy<7.0,>=6.0->clean-text) (0.2.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandas>=1.3->chromadb) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.12.0)
# Requirement already satisfied: monotonic>=1.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests>=2.28->chromadb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (4.29.1)
# Requirement already satisfied: tqdm in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (2.0.1)
# Requirement already satisfied: torchvision in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (0.15.2)
# Requirement already satisfied: scikit-learn in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (1.2.2)
# Requirement already satisfied: scipy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (1.10.1)
# Requirement already satisfied: nltk in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (3.8.1)
# Requirement already satisfied: sentencepiece in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sentence-transformers>=2.2.2->chromadb) (0.14.1)
# Requirement already satisfied: click>=7.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.5.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: websockets>=10.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: filelock in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb) (3.12.0)
# Requirement already satisfied: fsspec in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb) (2023.5.0)
# Requirement already satisfied: packaging>=20.9 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->chromadb) (23.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from starlette<0.27.0,>=0.26.1->fastapi>=0.85.1->chromadb) (3.6.2)
# Requirement already satisfied: sympy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (1.12)
# Requirement already satisfied: networkx in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (3.1)
# Requirement already satisfied: jinja2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (2.0.0)
# Requirement already satisfied: setuptools in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (67.7.2)
# Requirement already satisfied: wheel in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (0.40.0)
# Requirement already satisfied: cmake in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (3.26.3)
# Requirement already satisfied: lit in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (16.0.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->chromadb) (0.13.3)
# Requirement already satisfied: joblib in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from nltk->sentence-transformers>=2.2.2->chromadb) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from scikit-learn->sentence-transformers>=2.2.2->chromadb) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from torchvision->sentence-transformers>=2.2.2->chromadb) (9.5.0)
# Requirement already satisfied: sniffio>=1.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from anyio<5,>=3.4.0->starlette<0.27.0,>=0.26.1->fastapi>=0.85.1->chromadb) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.2->chromadb) (1.3.0)
# Requirement already satisfied: pandoc in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (2.3)
# Requirement already satisfied: plumbum in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandoc) (1.8.1)
# Requirement already satisfied: ply in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandoc) (3.11)
# Requirement already satisfied: unstructured[local-inference] in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.5.9)
# Requirement already satisfied: argilla in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (1.7.0)
# Requirement already satisfied: lxml in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (4.9.2)
# Requirement already satisfied: msg-parser in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (1.2.0)
# Requirement already satisfied: nltk in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (3.8.1)
# Requirement already satisfied: openpyxl in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (3.1.2)
# Requirement already satisfied: pandas in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (1.5.3)
# Requirement already satisfied: pillow in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (9.5.0)
# Requirement already satisfied: pypandoc in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (1.11)
# Requirement already satisfied: python-docx in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (0.8.11)
# Requirement already satisfied: python-pptx in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (0.6.21)
# Requirement already satisfied: python-magic in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (0.4.27)
# Requirement already satisfied: markdown in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (3.4.3)
# Requirement already satisfied: requests in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (2.29.0)
# Requirement already satisfied: certifi>=2022.12.07 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (2023.5.7)
# Requirement already satisfied: unstructured-inference~=0.2.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured[local-inference]) (0.2.4)
# Requirement already satisfied: fastapi in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from unstructured-inference~=0.2.4->unstructured[local-inference]) (0.95.1)
# ...
# Requirement already satisfied: cloudpickle in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.65.0)
# Requirement already satisfied: tensorboard in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.13.0)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.1.9)
# Requirement already satisfied: future in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.18.3)
# Requirement already satisfied: pydot in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.4.2)
# Requirement already satisfied: omegaconf>=2.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.3.2)
# Requirement already satisfied: black==21.4b2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (21.4b2)
# Requirement already satisfied: click>=7.1.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (8.1.3)
# Requirement already satisfied: appdirs in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.4.4)
# Requirement already satisfied: toml>=0.10.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.10.2)
# Requirement already satisfied: regex>=2020.1.8 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2023.5.5)
# Requirement already satisfied: pathspec<1,>=0.8.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.11.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from black==21.4b2->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.0.0)
# Requirement already satisfied: numpy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (6.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.9.3)
# Requirement already satisfied: packaging in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (23.1)
# Requirement already satisfied: portalocker in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.8.2)
# Requirement already satisfied: absl-py>=0.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.54.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.18.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.23.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.29.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.3.4)
# Requirement already satisfied: wheel>=0.26 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.12.0)
# Requirement already satisfied: urllib3<2.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.26.15)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git@v0.6#egg=detectron2) (3.2.2)
# Requirement already satisfied: layoutparser in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (0.3.4)
# Requirement already satisfied: numpy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (1.23.5)
# Requirement already satisfied: opencv-python in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (4.6.0.66)
# Requirement already satisfied: scipy in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (1.10.1)
# Requirement already satisfied: pandas in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (1.5.3)
# Requirement already satisfied: pillow in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (9.5.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (6.0)
# Requirement already satisfied: iopath in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (0.1.9)
# Requirement already satisfied: pdfplumber in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (0.9.0)
# Requirement already satisfied: pdf2image in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from layoutparser) (1.16.3)
# Requirement already satisfied: tqdm in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from iopath->layoutparser) (4.65.0)
# Requirement already satisfied: portalocker in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from iopath->layoutparser) (2.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandas->layoutparser) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pandas->layoutparser) (2023.3)
# Requirement already satisfied: pdfminer.six==20221105 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfplumber->layoutparser) (20221105)
# Requirement already satisfied: Wand>=0.6.10 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfplumber->layoutparser) (0.6.11)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber->layoutparser) (3.1.0)
# Requirement already satisfied: cryptography>=36.0.0 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from pdfminer.six==20221105->pdfplumber->layoutparser) (40.0.2)
# Requirement already satisfied: six>=1.5 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->layoutparser) (1.12.0)
# Requirement already satisfied: cffi>=1.12 in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser) (1.15.1)
# Requirement already satisfied: pycparser in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber->layoutparser) (2.21)
# Requirement already satisfied: pypdf in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: unidecode in /home/yudhanjaya/anaconda3/envs/bookwormenv/lib/python3.11/site-packages (1.3.6)

# %%
OPENAI_API_KEY = "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"
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
def examinelibrary():
    # Define the extensions we're looking for
    extensions = ['txt', 'md', 'pdf', 'doc', 'docx']

    # Initialize a counter
    counter = 0

    # Scan the directory
    for extension in extensions:
        counter += len(glob.glob("/books/*." + extension))
        
    # Initialize library as dict and load documents into it
    library = {}
    for extension in extensions:
        for file_name in glob.glob("books/*." + extension):
            content = ""
            if extension in ['txt', 'md']:
                loader = TextLoader(file_name)
            elif extension in ['doc', 'docx']:
                loader = UnstructuredWordDocumentLoader(file_name) 
            elif extension == 'pdf':
                loader = PyPDFLoader(file_name)
            elif extension == 'epub':  
                loader = UnstructuredEPubLoader(file_name) 
        # Load the contents of the file        
        documents = loader.load()
        # Add the file and its contents to the library
        library[file_name] = documents
        
    # Display the count of files detected   
    return(library, counter)

# Split the texts in the library into chunks
def processtext(library):
    text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
    texts = []
    for file_name in library:
          texts += text_splitter.split_documents(library[file_name])
    return texts

# Produce a librarian (database of embedded texts)
def prodlibrarian():
    library,counter = examinelibrary()
    texts = processtext(library)
    embeddings = OpenAIEmbeddings()
    db = Chroma.from_documents(texts, embeddings)
    return db

# Call prodlibrarian on startup
db = prodlibrarian()

# Initialize language model and qa chain
llm = OpenAI(temperature=0)
from langchain.chains.question_answering import load_qa_chain
chain = load_qa_chain(llm, chain_type="stuff")

# Call prodlibrarian and display progress
def scan(progress=gr.Progress()):
    progress(0.2, desc="Examining /books folder ...")
    time.sleep(1)
    progress(0.4, desc="Counting documents ...")
    time.sleep(1.5)
    progress(0.6, desc="Generating embeddings ...")
    time.sleep(1.5)
    db = prodlibrarian()
    return "Librarian found and embedded " + str(counter) + " documents."

# Main query code.
def ask(query, progress=gr.Progress()):
    progress(0.1, desc="Scanning embedded documents for matches ...")
    time.sleep(1)
    progress(0.2, desc="Assembling request...")
    time.sleep(1.5)
    progress(0.4, desc="Appending citations and metadata ...")
    time.sleep(1.5)
    progress(0.5, desc="Talking to LLM for answers ...")
    time.sleep(1.5)
    #generate docs which are texts relevant to the query
    docs = db.similarity_search(query) 
    #some muckwork to log sources
    x = 0
    citations = ""
    for x in range(len(docs)): 
        citations += docs[x].metadata['source'] + " in page: " + str(docs[x].metadata['page'])  + "\n"
        
    #calls llm with the query and relevant docs in hand and returns both the response and the sources    
    librarianoutput = f"{chain.run(input_documents=docs, question=query)}"
    output = "Answer: \n" + librarianoutput + "\n\nI found this in: \n" +  str(citations) 
    return (output)

#Gradio UI
with gr.Blocks() as app:
    
    with gr.Row():
        gr.Markdown("# Welcome to your antilibrary!")
        scan_btn = gr.Button("Scan the library again.")
        
    query = gr.Textbox(label="What can I help you find?")
    output = gr.Textbox(label="Response:")
    ask_btn = gr.Button("Ask Librarian")
    
    ask_btn.click(fn=ask, inputs=query, outputs=output)
    scan_btn.click(fn=scan, outputs=output)
    gr.Markdown("*...a private library is not an ego-boosting appendage but a research tool. The library should contain as much of what you do not know ... You will accumulate more knowledge and more books as you grow older, and the growing number of unread books on the shelves will look at you menacingly. Indeed, the more you know, the larger the rows of unread books. Let us call this collection of unread books an antilibrary.* \n - Nassim Nicholas Taleb, The Black Swan")
app.queue(concurrency_count=10).launch()
# Out:
# Created a chunk of size 1081, which is longer than the specified 1000
# Using embedded DuckDB without persistence: data will be transient
# Running on local URL:  http://127.0.0.1:7896
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7896/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
